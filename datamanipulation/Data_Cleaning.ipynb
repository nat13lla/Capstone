# %% [markdown]
# <a href="https://colab.research.google.com/github/nat13lla/Capstone/blob/main/datamanipulation/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in the final_dataframe.csv from github
df = pd.read_csv("https://raw.githubusercontent.com/nat13lla/Capstone/main/data_files/final_dataframe.csv")

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    results_id  Season  Round           Race Name  \
# 0           1    2022      1  Bahrain Grand Prix
# 1           2    2022      1  Bahrain Grand Prix
# 2           3    2022      1  Bahrain Grand Prix
# 3           4    2022      1  Bahrain Grand Prix
# 4           5    2022      1  Bahrain Grand Prix
#
#                     Circuit Name         driverId givenName familyName  \
# 0  Bahrain International Circuit          leclerc   Charles    Leclerc
# 1  Bahrain International Circuit            sainz    Carlos      Sainz
# 2  Bahrain International Circuit         hamilton     Lewis   Hamilton
# 3  Bahrain International Circuit          russell    George    Russell
# 4  Bahrain International Circuit  kevin_magnussen     Kevin  Magnussen
#
#    perm_number code constructorId constructorname nationality  position  \
# 0           16  LEC       ferrari         Ferrari  Monegasque         1
# 1           55  SAI       ferrari         Ferrari     Spanish         2
# 2           44  HAM      mercedes        Mercedes     British         3
# 3           63  RUS      mercedes        Mercedes     British         4
# 4           20  MAG          haas    Haas F1 Team      Danish         5
#
#    points    status  grid  laps   t_millis       t_time  fl_av_speed  \
# 0      26  Finished     1    57  5853584.0  1:37:33.584      206.018
# 1      18  Finished     3    57  5859182.0       +5.598      203.501
# 2      15  Finished     5    57  5863259.0       +9.675      202.469
# 3      12  Finished     9    57  5864795.0      +11.211      202.313
# 4      10  Finished     7    57  5868338.0      +14.754      201.641
#
#     fl_time  fl_lap_no  fl_rank  race_id        date       time  drivers_id  \
# 0  1:34.570       51.0      1.0        1  2022-03-20  15:00:00Z           9
# 1  1:35.740       52.0      3.0        1  2022-03-20  15:00:00Z          16
# 2  1:36.228       53.0      5.0        1  2022-03-20  15:00:00Z           6
# 3  1:36.302       56.0      6.0        1  2022-03-20  15:00:00Z          15
# 4  1:36.623       53.0      8.0        1  2022-03-20  15:00:00Z          10
#
#   dateOfBirth  constructors_id team_nationality  circuit_id location  country  \
# 0  1997-10-16                5          Italian           1   Sakhir  Bahrain
# 1  1994-09-01                5          Italian           1   Sakhir  Bahrain
# 2  1985-01-07                8           German           1   Sakhir  Bahrain
# 3  1998-02-15                8           German           1   Sakhir  Bahrain
# 4  1992-10-05                6         American           1   Sakhir  Bahrain
#
#        lat      lng
# 0  26.0325  50.5106
# 1  26.0325  50.5106
# 2  26.0325  50.5106
# 3  26.0325  50.5106
# 4  26.0325  50.5106

# %%
df.columns
# Out:
# Index(['results_id', 'Season', 'Round', 'Race Name', 'Circuit Name',
#        'driverId', 'givenName', 'familyName', 'perm_number', 'code',
#        'constructorId', 'constructorname', 'nationality', 'position', 'points',
#        'status', 'grid', 'laps', 't_millis', 't_time', 'fl_av_speed',
#        'fl_time', 'fl_lap_no', 'fl_rank', 'race_id', 'date', 'time',
#        'drivers_id', 'dateOfBirth', 'constructors_id', 'team_nationality',
#        'circuit_id', 'location', 'country', 'lat', 'lng'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Re-order Columns

# %%
# Look at all Column Titles
df.columns
# Out:
# Index(['results_id', 'Season', 'Round', 'Race Name', 'Circuit Name',
#        'driverId', 'givenName', 'familyName', 'perm_number', 'code',
#        'constructorId', 'constructorname', 'nationality', 'position', 'points',
#        'status', 'grid', 'laps', 't_millis', 't_time', 'fl_av_speed',
#        'fl_time', 'fl_lap_no', 'fl_rank', 'race_id', 'date', 'time',
#        'drivers_id', 'dateOfBirth', 'constructors_id', 'team_nationality',
#        'circuit_id', 'location', 'country', 'lat', 'lng'],
#       dtype='object')

# %%
# Reorder
df = df[['results_id', 'Season', 'Round', 'Race Name', 'race_id', 'date', 'time',
         'Circuit Name','circuit_id', 'location', 'country', 'lat', 'lng',
         'drivers_id', 'driverId','givenName', 'familyName', 'code','perm_number', 'nationality','dateOfBirth',
         'constructors_id', 'constructorId','constructorname', 'team_nationality',
         'grid','position', 'points', 'status', 'laps',
         't_millis', 't_time', 'fl_av_speed', 'fl_time', 'fl_lap_no', 'fl_rank']]

# %%
df.head()
# Out:
#    results_id  Season  Round           Race Name  race_id        date  \
# 0           1    2022      1  Bahrain Grand Prix        1  2022-03-20
# 1           2    2022      1  Bahrain Grand Prix        1  2022-03-20
# 2           3    2022      1  Bahrain Grand Prix        1  2022-03-20
# 3           4    2022      1  Bahrain Grand Prix        1  2022-03-20
# 4           5    2022      1  Bahrain Grand Prix        1  2022-03-20
#
#         time                   Circuit Name  circuit_id location  country  \
# 0  15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 1  15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 2  15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 3  15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 4  15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
#
#        lat      lng  drivers_id         driverId givenName familyName code  \
# 0  26.0325  50.5106           9          leclerc   Charles    Leclerc  LEC
# 1  26.0325  50.5106          16            sainz    Carlos      Sainz  SAI
# 2  26.0325  50.5106           6         hamilton     Lewis   Hamilton  HAM
# 3  26.0325  50.5106          15          russell    George    Russell  RUS
# 4  26.0325  50.5106          10  kevin_magnussen     Kevin  Magnussen  MAG
#
#    perm_number nationality dateOfBirth  constructors_id constructorId  \
# 0           16  Monegasque  1997-10-16                5       ferrari
# 1           55     Spanish  1994-09-01                5       ferrari
# 2           44     British  1985-01-07                8      mercedes
# 3           63     British  1998-02-15                8      mercedes
# 4           20      Danish  1992-10-05                6          haas
#
#   constructorname team_nationality  grid  position  points    status  laps  \
# 0         Ferrari          Italian     1         1      26  Finished    57
# 1         Ferrari          Italian     3         2      18  Finished    57
# 2        Mercedes           German     5         3      15  Finished    57
# 3        Mercedes           German     9         4      12  Finished    57
# 4    Haas F1 Team         American     7         5      10  Finished    57
#
#     t_millis       t_time  fl_av_speed   fl_time  fl_lap_no  fl_rank
# 0  5853584.0  1:37:33.584      206.018  1:34.570       51.0      1.0
# 1  5859182.0       +5.598      203.501  1:35.740       52.0      3.0
# 2  5863259.0       +9.675      202.469  1:36.228       53.0      5.0
# 3  5864795.0      +11.211      202.313  1:36.302       56.0      6.0
# 4  5868338.0      +14.754      201.641  1:36.623       53.0      8.0

# %% [markdown]
# ### Rename Columns

# %%
# rename the columns
df.rename(columns={'Season':'race_year','Round':'round','Race Name':'race_name',
                   'date':'date_of_race', 'time':'time_of_race','Circuit Name':'circuit_name',
                   'nationality':'driver_nationality','dateOfBirth':'dob','constructorname':'constructor_name','team_nationality':'constructor_nationality',
                   'grid':'start_position', 'position':'end_position','points':'points_gained',
                   'status':'race_status','laps':'laps_done',
                   't_millis':'race_millis','t_time':'race_time'},inplace=True)

# %%
df.head()
# Out:
#    results_id  race_year  round           race_name  race_id date_of_race  \
# 0           1       2022      1  Bahrain Grand Prix        1   2022-03-20
# 1           2       2022      1  Bahrain Grand Prix        1   2022-03-20
# 2           3       2022      1  Bahrain Grand Prix        1   2022-03-20
# 3           4       2022      1  Bahrain Grand Prix        1   2022-03-20
# 4           5       2022      1  Bahrain Grand Prix        1   2022-03-20
#
#   time_of_race                   circuit_name  circuit_id location  country  \
# 0    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 1    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 2    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 3    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 4    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
#
#        lat      lng  drivers_id         driverId givenName familyName code  \
# 0  26.0325  50.5106           9          leclerc   Charles    Leclerc  LEC
# 1  26.0325  50.5106          16            sainz    Carlos      Sainz  SAI
# 2  26.0325  50.5106           6         hamilton     Lewis   Hamilton  HAM
# 3  26.0325  50.5106          15          russell    George    Russell  RUS
# 4  26.0325  50.5106          10  kevin_magnussen     Kevin  Magnussen  MAG
#
#    perm_number driver_nationality         dob  constructors_id constructorId  \
# 0           16         Monegasque  1997-10-16                5       ferrari
# 1           55            Spanish  1994-09-01                5       ferrari
# 2           44            British  1985-01-07                8      mercedes
# 3           63            British  1998-02-15                8      mercedes
# 4           20             Danish  1992-10-05                6          haas
#
#   constructor_name constructor_nationality  start_position  end_position  \
# 0          Ferrari                 Italian               1             1
# 1          Ferrari                 Italian               3             2
# 2         Mercedes                  German               5             3
# 3         Mercedes                  German               9             4
# 4     Haas F1 Team                American               7             5
#
#    points_gained race_status  laps_done  race_millis    race_time  \
# 0             26    Finished         57    5853584.0  1:37:33.584
# 1             18    Finished         57    5859182.0       +5.598
# 2             15    Finished         57    5863259.0       +9.675
# 3             12    Finished         57    5864795.0      +11.211
# 4             10    Finished         57    5868338.0      +14.754
#
#    fl_av_speed   fl_time  fl_lap_no  fl_rank
# 0      206.018  1:34.570       51.0      1.0
# 1      203.501  1:35.740       52.0      3.0
# 2      202.469  1:36.228       53.0      5.0
# 3      202.313  1:36.302       56.0      6.0
# 4      201.641  1:36.623       53.0      8.0

# %%
# Download the Dataframe as CSV
df.to_csv('ordered_data.csv', index=False)

# %% [markdown]
# ### Combine name columns

# %%
# Combine first and second name to create a driver name column
df['driver_name'] = df['givenName']+' '+df['familyName']
# Drop the other columns (givenName, familyName)
df = df.drop(['givenName','familyName' ], axis = 1)

# %%
df.head()
# Out:
#    results_id  race_year  round           race_name  race_id date_of_race  \
# 0           1       2022      1  Bahrain Grand Prix        1   2022-03-20
# 1           2       2022      1  Bahrain Grand Prix        1   2022-03-20
# 2           3       2022      1  Bahrain Grand Prix        1   2022-03-20
# 3           4       2022      1  Bahrain Grand Prix        1   2022-03-20
# 4           5       2022      1  Bahrain Grand Prix        1   2022-03-20
#
#   time_of_race                   circuit_name  circuit_id location  country  \
# 0    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 1    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 2    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 3    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 4    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
#
#        lat      lng  drivers_id         driverId code  perm_number  \
# 0  26.0325  50.5106           9          leclerc  LEC           16
# 1  26.0325  50.5106          16            sainz  SAI           55
# 2  26.0325  50.5106           6         hamilton  HAM           44
# 3  26.0325  50.5106          15          russell  RUS           63
# 4  26.0325  50.5106          10  kevin_magnussen  MAG           20
#
#   driver_nationality         dob  constructors_id constructorId  \
# 0         Monegasque  1997-10-16                5       ferrari
# 1            Spanish  1994-09-01                5       ferrari
# 2            British  1985-01-07                8      mercedes
# 3            British  1998-02-15                8      mercedes
# 4             Danish  1992-10-05                6          haas
#
#   constructor_name constructor_nationality  start_position  end_position  \
# 0          Ferrari                 Italian               1             1
# 1          Ferrari                 Italian               3             2
# 2         Mercedes                  German               5             3
# 3         Mercedes                  German               9             4
# 4     Haas F1 Team                American               7             5
#
#    points_gained race_status  laps_done  race_millis    race_time  \
# 0             26    Finished         57    5853584.0  1:37:33.584
# 1             18    Finished         57    5859182.0       +5.598
# 2             15    Finished         57    5863259.0       +9.675
# 3             12    Finished         57    5864795.0      +11.211
# 4             10    Finished         57    5868338.0      +14.754
#
#    fl_av_speed   fl_time  fl_lap_no  fl_rank      driver_name
# 0      206.018  1:34.570       51.0      1.0  Charles Leclerc
# 1      203.501  1:35.740       52.0      3.0     Carlos Sainz
# 2      202.469  1:36.228       53.0      5.0   Lewis Hamilton
# 3      202.313  1:36.302       56.0      6.0   George Russell
# 4      201.641  1:36.623       53.0      8.0  Kevin Magnussen

# %% [markdown]
# ### Add places_gained column

# %%
# Add places Gained Column
df['places_gained'] = df['start_position']-df['end_position']
df.head(10)
# Out:
#    results_id  race_year  round           race_name  race_id date_of_race  \
# 0           1       2022      1  Bahrain Grand Prix        1   2022-03-20
# 1           2       2022      1  Bahrain Grand Prix        1   2022-03-20
# 2           3       2022      1  Bahrain Grand Prix        1   2022-03-20
# 3           4       2022      1  Bahrain Grand Prix        1   2022-03-20
# 4           5       2022      1  Bahrain Grand Prix        1   2022-03-20
# 5           6       2022      1  Bahrain Grand Prix        1   2022-03-20
# 6           7       2022      1  Bahrain Grand Prix        1   2022-03-20
# 7           8       2022      1  Bahrain Grand Prix        1   2022-03-20
# 8           9       2022      1  Bahrain Grand Prix        1   2022-03-20
# 9          10       2022      1  Bahrain Grand Prix        1   2022-03-20
#
#   time_of_race                   circuit_name  circuit_id location  country  \
# 0    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 1    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 2    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 3    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 4    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 5    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 6    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 7    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 8    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 9    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
#
#        lat      lng  drivers_id         driverId code  perm_number  \
# 0  26.0325  50.5106           9          leclerc  LEC           16
# 1  26.0325  50.5106          16            sainz  SAI           55
# 2  26.0325  50.5106           6         hamilton  HAM           44
# 3  26.0325  50.5106          15          russell  RUS           63
# 4  26.0325  50.5106          10  kevin_magnussen  MAG           20
# 5  26.0325  50.5106           3           bottas  BOT           77
# 6  26.0325  50.5106          12             ocon  OCO           31
# 7  26.0325  50.5106          19          tsunoda  TSU           22
# 8  26.0325  50.5106           2           alonso  ALO           14
# 9  26.0325  50.5106          22             zhou  ZHO           24
#
#   driver_nationality         dob  constructors_id constructorId  \
# 0         Monegasque  1997-10-16                5       ferrari
# 1            Spanish  1994-09-01                5       ferrari
# 2            British  1985-01-07                8      mercedes
# 3            British  1998-02-15                8      mercedes
# 4             Danish  1992-10-05                6          haas
# 5            Finnish  1989-08-28                1          alfa
# 6             French  1996-09-17                3        alpine
# 7           Japanese  2000-05-11                2    alphatauri
# 8            Spanish  1981-07-29                3        alpine
# 9            Chinese  1999-05-30                1          alfa
#
#   constructor_name constructor_nationality  start_position  end_position  \
# 0          Ferrari                 Italian               1             1
# 1          Ferrari                 Italian               3             2
# 2         Mercedes                  German               5             3
# 3         Mercedes                  German               9             4
# 4     Haas F1 Team                American               7             5
# 5       Alfa Romeo                   Swiss               6             6
# 6   Alpine F1 Team                  French              11             7
# 7       AlphaTauri                 Italian              16             8
# 8   Alpine F1 Team                  French               8             9
# 9       Alfa Romeo                   Swiss              15            10
#
#    points_gained race_status  laps_done  race_millis    race_time  \
# 0             26    Finished         57    5853584.0  1:37:33.584
# 1             18    Finished         57    5859182.0       +5.598
# 2             15    Finished         57    5863259.0       +9.675
# 3             12    Finished         57    5864795.0      +11.211
# 4             10    Finished         57    5868338.0      +14.754
# 5              8    Finished         57    5869703.0      +16.119
# 6              6    Finished         57    5873007.0      +19.423
# 7              4    Finished         57    5873970.0      +20.386
# 8              2    Finished         57    5875974.0      +22.390
# 9              1    Finished         57    5876648.0      +23.064
#
#    fl_av_speed   fl_time  fl_lap_no  fl_rank      driver_name  places_gained
# 0      206.018  1:34.570       51.0      1.0  Charles Leclerc              0
# 1      203.501  1:35.740       52.0      3.0     Carlos Sainz              1
# 2      202.469  1:36.228       53.0      5.0   Lewis Hamilton              2
# 3      202.313  1:36.302       56.0      6.0   George Russell              5
# 4      201.641  1:36.623       53.0      8.0  Kevin Magnussen              2
# 5      201.691  1:36.599       53.0      7.0  Valtteri Bottas              0
# 6      200.630  1:37.110       53.0     14.0     Esteban Ocon              4
# 7      200.642  1:37.104       53.0     13.0     Yuki Tsunoda              8
# 8      201.412  1:36.733       44.0     10.0  Fernando Alonso             -1
# 9      201.512  1:36.685       39.0      9.0      Guanyu Zhou              5

# %%
df
# Out:
#      results_id  race_year  round                 race_name  race_id  \
# 0             1       2022      1        Bahrain Grand Prix        1
# 1             2       2022      1        Bahrain Grand Prix        1
# 2             3       2022      1        Bahrain Grand Prix        1
# 3             4       2022      1        Bahrain Grand Prix        1
# 4             5       2022      1        Bahrain Grand Prix        1
# ..          ...        ...    ...                       ...      ...
# 915         916       2024      2  Saudi Arabian Grand Prix       46
# 916         917       2024      2  Saudi Arabian Grand Prix       46
# 917         918       2024      2  Saudi Arabian Grand Prix       46
# 918         919       2024      2  Saudi Arabian Grand Prix       46
# 919         920       2024      2  Saudi Arabian Grand Prix       46
#
#     date_of_race time_of_race                   circuit_name  circuit_id  \
# 0     2022-03-20    15:00:00Z  Bahrain International Circuit           1
# 1     2022-03-20    15:00:00Z  Bahrain International Circuit           1
# 2     2022-03-20    15:00:00Z  Bahrain International Circuit           1
# 3     2022-03-20    15:00:00Z  Bahrain International Circuit           1
# 4     2022-03-20    15:00:00Z  Bahrain International Circuit           1
# ..           ...          ...                            ...         ...
# 915   2024-03-09    17:00:00Z        Jeddah Corniche Circuit           2
# 916   2024-03-09    17:00:00Z        Jeddah Corniche Circuit           2
# 917   2024-03-09    17:00:00Z        Jeddah Corniche Circuit           2
# 918   2024-03-09    17:00:00Z        Jeddah Corniche Circuit           2
# 919   2024-03-09    17:00:00Z        Jeddah Corniche Circuit           2
#
#     location       country      lat      lng  drivers_id         driverId  \
# 0     Sakhir       Bahrain  26.0325  50.5106           9          leclerc
# 1     Sakhir       Bahrain  26.0325  50.5106          16            sainz
# 2     Sakhir       Bahrain  26.0325  50.5106           6         hamilton
# 3     Sakhir       Bahrain  26.0325  50.5106          15          russell
# 4     Sakhir       Bahrain  26.0325  50.5106          10  kevin_magnussen
# ..       ...           ...      ...      ...         ...              ...
# 915   Jeddah  Saudi Arabia  21.6319  39.1044          14        ricciardo
# 916   Jeddah  Saudi Arabia  21.6319  39.1044           3           bottas
# 917   Jeddah  Saudi Arabia  21.6319  39.1044          22             zhou
# 918   Jeddah  Saudi Arabia  21.6319  39.1044          18           stroll
# 919   Jeddah  Saudi Arabia  21.6319  39.1044           5            gasly
#
#     code  perm_number driver_nationality         dob  constructors_id  \
# 0    LEC           16         Monegasque  1997-10-16                5
# 1    SAI           55            Spanish  1994-09-01                5
# 2    HAM           44            British  1985-01-07                8
# 3    RUS           63            British  1998-02-15                8
# 4    MAG           20             Danish  1992-10-05                6
# ..   ...          ...                ...         ...              ...
# 915  RIC            3         Australian  1989-07-01               11
# 916  BOT           77            Finnish  1989-08-28               12
# 917  ZHO           24            Chinese  1999-05-30               12
# 918  STR           18           Canadian  1998-10-29                4
# 919  GAS           10             French  1996-02-07                3
#
#     constructorId constructor_name constructor_nationality  start_position  \
# 0         ferrari          Ferrari                 Italian               1
# 1         ferrari          Ferrari                 Italian               3
# 2        mercedes         Mercedes                  German               5
# 3        mercedes         Mercedes                  German               9
# 4            haas     Haas F1 Team                American               7
# ..            ...              ...                     ...             ...
# 915            rb       RB F1 Team                 Italian              14
# 916        sauber           Sauber                   Swiss              16
# 917        sauber           Sauber                   Swiss              20
# 918  aston_martin     Aston Martin                 British              10
# 919        alpine   Alpine F1 Team                  French              18
#
#      end_position  points_gained race_status  laps_done  race_millis  \
# 0               1             26    Finished         57    5853584.0
# 1               2             18    Finished         57    5859182.0
# 2               3             15    Finished         57    5863259.0
# 3               4             12    Finished         57    5864795.0
# 4               5             10    Finished         57    5868338.0
# ..            ...            ...         ...        ...          ...
# 915            16              0      +1 Lap         49          NaN
# 916            17              0      +1 Lap         49          NaN
# 917            18              0      +1 Lap         49          NaN
# 918            19              0    Accident          5          NaN
# 919            20              0     Gearbox          1          NaN
#
#        race_time  fl_av_speed   fl_time  fl_lap_no  fl_rank       driver_name  \
# 0    1:37:33.584      206.018  1:34.570       51.0      1.0   Charles Leclerc
# 1         +5.598      203.501  1:35.740       52.0      3.0      Carlos Sainz
# 2         +9.675      202.469  1:36.228       53.0      5.0    Lewis Hamilton
# 3        +11.211      202.313  1:36.302       56.0      6.0    George Russell
# 4        +14.754      201.641  1:36.623       53.0      8.0   Kevin Magnussen
# ..           ...          ...       ...        ...      ...               ...
# 915          NaN      238.166  1:33.323       47.0     16.0  Daniel Ricciardo
# 916          NaN      239.751  1:32.706       49.0     14.0   Valtteri Bottas
# 917          NaN      241.046  1:32.208       49.0      6.0       Guanyu Zhou
# 918          NaN      232.591  1:35.560        5.0     19.0      Lance Stroll
# 919          NaN          NaN       NaN        NaN      NaN      Pierre Gasly
#
#      places_gained
# 0                0
# 1                1
# 2                2
# 3                5
# 4                2
# ..             ...
# 915             -2
# 916             -1
# 917              2
# 918             -9
# 919             -2
#
# [920 rows x 36 columns]

# %% [markdown]
# ### Change type of date/type columns
# LogReg doesn't like date/time inputs so well have to do somthing about that!
# * date_of_race --> to date
# * dob --> to date
# * time_of race --> to time

# %% [markdown]
# #### Date Changes

# %%
# Change 'date_of_race' from obj- > date
df['date_of_race'] = pd.to_datetime(df['date_of_race'])

# %%
# Extract month and Day as columns
df['race_month'] = df['date_of_race'].dt.month
df['race_day'] = df['date_of_race'].dt.day

# %%
# Change 'dob' from obj- > time
df['dob'] = pd.to_datetime(df['dob'])

# %%
df.head()
# Out:
#    results_id  race_year  round           race_name  race_id date_of_race  \
# 0           1       2022      1  Bahrain Grand Prix        1   2022-03-20
# 1           2       2022      1  Bahrain Grand Prix        1   2022-03-20
# 2           3       2022      1  Bahrain Grand Prix        1   2022-03-20
# 3           4       2022      1  Bahrain Grand Prix        1   2022-03-20
# 4           5       2022      1  Bahrain Grand Prix        1   2022-03-20
#
#   time_of_race                   circuit_name  circuit_id location  country  \
# 0    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 1    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 2    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 3    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 4    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
#
#        lat      lng  drivers_id         driverId code  perm_number  \
# 0  26.0325  50.5106           9          leclerc  LEC           16
# 1  26.0325  50.5106          16            sainz  SAI           55
# 2  26.0325  50.5106           6         hamilton  HAM           44
# 3  26.0325  50.5106          15          russell  RUS           63
# 4  26.0325  50.5106          10  kevin_magnussen  MAG           20
#
#   driver_nationality        dob  constructors_id constructorId  \
# 0         Monegasque 1997-10-16                5       ferrari
# 1            Spanish 1994-09-01                5       ferrari
# 2            British 1985-01-07                8      mercedes
# 3            British 1998-02-15                8      mercedes
# 4             Danish 1992-10-05                6          haas
#
#   constructor_name constructor_nationality  start_position  end_position  \
# 0          Ferrari                 Italian               1             1
# 1          Ferrari                 Italian               3             2
# 2         Mercedes                  German               5             3
# 3         Mercedes                  German               9             4
# 4     Haas F1 Team                American               7             5
#
#    points_gained race_status  laps_done  race_millis    race_time  \
# 0             26    Finished         57    5853584.0  1:37:33.584
# 1             18    Finished         57    5859182.0       +5.598
# 2             15    Finished         57    5863259.0       +9.675
# 3             12    Finished         57    5864795.0      +11.211
# 4             10    Finished         57    5868338.0      +14.754
#
#    fl_av_speed   fl_time  fl_lap_no  fl_rank      driver_name  places_gained  \
# 0      206.018  1:34.570       51.0      1.0  Charles Leclerc              0
# 1      203.501  1:35.740       52.0      3.0     Carlos Sainz              1
# 2      202.469  1:36.228       53.0      5.0   Lewis Hamilton              2
# 3      202.313  1:36.302       56.0      6.0   George Russell              5
# 4      201.641  1:36.623       53.0      8.0  Kevin Magnussen              2
#
#    race_month  race_day
# 0           3        20
# 1           3        20
# 2           3        20
# 3           3        20
# 4           3        20

# %%
# Create an Age column that shows the age at each gp in days
df['age_in_days'] = (df['date_of_race'] - df['dob']).dt.days
df.head()
# Out:
#    results_id  race_year  round           race_name  race_id date_of_race  \
# 0           1       2022      1  Bahrain Grand Prix        1   2022-03-20
# 1           2       2022      1  Bahrain Grand Prix        1   2022-03-20
# 2           3       2022      1  Bahrain Grand Prix        1   2022-03-20
# 3           4       2022      1  Bahrain Grand Prix        1   2022-03-20
# 4           5       2022      1  Bahrain Grand Prix        1   2022-03-20
#
#   time_of_race                   circuit_name  circuit_id location  country  \
# 0    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 1    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 2    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 3    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
# 4    15:00:00Z  Bahrain International Circuit           1   Sakhir  Bahrain
#
#        lat      lng  drivers_id         driverId code  perm_number  \
# 0  26.0325  50.5106           9          leclerc  LEC           16
# 1  26.0325  50.5106          16            sainz  SAI           55
# 2  26.0325  50.5106           6         hamilton  HAM           44
# 3  26.0325  50.5106          15          russell  RUS           63
# 4  26.0325  50.5106          10  kevin_magnussen  MAG           20
#
#   driver_nationality        dob  constructors_id constructorId  \
# 0         Monegasque 1997-10-16                5       ferrari
# 1            Spanish 1994-09-01                5       ferrari
# 2            British 1985-01-07                8      mercedes
# 3            British 1998-02-15                8      mercedes
# 4             Danish 1992-10-05                6          haas
#
#   constructor_name constructor_nationality  start_position  end_position  \
# 0          Ferrari                 Italian               1             1
# 1          Ferrari                 Italian               3             2
# 2         Mercedes                  German               5             3
# 3         Mercedes                  German               9             4
# 4     Haas F1 Team                American               7             5
#
#    points_gained race_status  laps_done  race_millis    race_time  \
# 0             26    Finished         57    5853584.0  1:37:33.584
# 1             18    Finished         57    5859182.0       +5.598
# 2             15    Finished         57    5863259.0       +9.675
# 3             12    Finished         57    5864795.0      +11.211
# 4             10    Finished         57    5868338.0      +14.754
#
#    fl_av_speed   fl_time  fl_lap_no  fl_rank      driver_name  places_gained  \
# 0      206.018  1:34.570       51.0      1.0  Charles Leclerc              0
# 1      203.501  1:35.740       52.0      3.0     Carlos Sainz              1
# 2      202.469  1:36.228       53.0      5.0   Lewis Hamilton              2
# 3      202.313  1:36.302       56.0      6.0   George Russell              5
# 4      201.641  1:36.623       53.0      8.0  Kevin Magnussen              2
#
#    race_month  race_day  age_in_days
# 0           3        20         8921
# 1           3        20        10062
# 2           3        20        13586
# 3           3        20         8799
# 4           3        20        10758

# %%
# now we have age in days we can get rid of dob
df = df.drop(['dob'], axis = 1)

# %%
# now we have ag in days we can get rid of dob
df = df.drop(['date_of_race'], axis = 1)

# %%
df.columns
# Out:
# Index(['results_id', 'race_year', 'round', 'race_name', 'race_id',
#        'time_of_race', 'circuit_name', 'circuit_id', 'location', 'country',
#        'lat', 'lng', 'drivers_id', 'driverId', 'code', 'perm_number',
#        'driver_nationality', 'constructors_id', 'constructorId',
#        'constructor_name', 'constructor_nationality', 'start_position',
#        'end_position', 'points_gained', 'race_status', 'laps_done',
#        'race_millis', 'race_time', 'fl_av_speed', 'fl_time', 'fl_lap_no',
#        'fl_rank', 'driver_name', 'places_gained', 'race_month', 'race_day',
#        'age_in_days'],
#       dtype='object')

# %%
# Reorder
df = df[['results_id', 'race_year','race_month', 'race_day', 'round', 'race_name', 'race_id',
       'time_of_race', 'circuit_name', 'circuit_id', 'location', 'country',
       'lat', 'lng', 'drivers_id', 'driverId', 'driver_name', 'code',
       'perm_number', 'driver_nationality', 'age_in_days', 'constructors_id', 'constructorId',
       'constructor_name', 'constructor_nationality', 'start_position',
       'end_position', 'points_gained', 'race_status', 'laps_done',
       'race_millis', 'race_time', 'fl_av_speed', 'fl_time', 'fl_lap_no',
       'fl_rank', 'places_gained', 'age_in_days']]

# %%
df
# Out:
#      results_id  race_year  race_month  race_day  round  \
# 0             1       2022           3        20      1
# 1             2       2022           3        20      1
# 2             3       2022           3        20      1
# 3             4       2022           3        20      1
# 4             5       2022           3        20      1
# ..          ...        ...         ...       ...    ...
# 915         916       2024           3         9      2
# 916         917       2024           3         9      2
# 917         918       2024           3         9      2
# 918         919       2024           3         9      2
# 919         920       2024           3         9      2
#
#                     race_name  race_id time_of_race  \
# 0          Bahrain Grand Prix        1    15:00:00Z
# 1          Bahrain Grand Prix        1    15:00:00Z
# 2          Bahrain Grand Prix        1    15:00:00Z
# 3          Bahrain Grand Prix        1    15:00:00Z
# 4          Bahrain Grand Prix        1    15:00:00Z
# ..                        ...      ...          ...
# 915  Saudi Arabian Grand Prix       46    17:00:00Z
# 916  Saudi Arabian Grand Prix       46    17:00:00Z
# 917  Saudi Arabian Grand Prix       46    17:00:00Z
# 918  Saudi Arabian Grand Prix       46    17:00:00Z
# 919  Saudi Arabian Grand Prix       46    17:00:00Z
#
#                       circuit_name  circuit_id location       country  \
# 0    Bahrain International Circuit           1   Sakhir       Bahrain
# 1    Bahrain International Circuit           1   Sakhir       Bahrain
# 2    Bahrain International Circuit           1   Sakhir       Bahrain
# 3    Bahrain International Circuit           1   Sakhir       Bahrain
# 4    Bahrain International Circuit           1   Sakhir       Bahrain
# ..                             ...         ...      ...           ...
# 915        Jeddah Corniche Circuit           2   Jeddah  Saudi Arabia
# 916        Jeddah Corniche Circuit           2   Jeddah  Saudi Arabia
# 917        Jeddah Corniche Circuit           2   Jeddah  Saudi Arabia
# 918        Jeddah Corniche Circuit           2   Jeddah  Saudi Arabia
# 919        Jeddah Corniche Circuit           2   Jeddah  Saudi Arabia
#
#          lat      lng  drivers_id         driverId       driver_name code  \
# 0    26.0325  50.5106           9          leclerc   Charles Leclerc  LEC
# 1    26.0325  50.5106          16            sainz      Carlos Sainz  SAI
# 2    26.0325  50.5106           6         hamilton    Lewis Hamilton  HAM
# 3    26.0325  50.5106          15          russell    George Russell  RUS
# 4    26.0325  50.5106          10  kevin_magnussen   Kevin Magnussen  MAG
# ..       ...      ...         ...              ...               ...  ...
# 915  21.6319  39.1044          14        ricciardo  Daniel Ricciardo  RIC
# 916  21.6319  39.1044           3           bottas   Valtteri Bottas  BOT
# 917  21.6319  39.1044          22             zhou       Guanyu Zhou  ZHO
# 918  21.6319  39.1044          18           stroll      Lance Stroll  STR
# 919  21.6319  39.1044           5            gasly      Pierre Gasly  GAS
#
#      perm_number driver_nationality  age_in_days  constructors_id  \
# 0             16         Monegasque         8921                5
# 1             55            Spanish        10062                5
# 2             44            British        13586                8
# 3             63            British         8799                8
# 4             20             Danish        10758                6
# ..           ...                ...          ...              ...
# 915            3         Australian        12670               11
# 916           77            Finnish        12612               12
# 917           24            Chinese         9050               12
# 918           18           Canadian         9263                4
# 919           10             French        10258                3
#
#     constructorId constructor_name constructor_nationality  start_position  \
# 0         ferrari          Ferrari                 Italian               1
# 1         ferrari          Ferrari                 Italian               3
# 2        mercedes         Mercedes                  German               5
# 3        mercedes         Mercedes                  German               9
# 4            haas     Haas F1 Team                American               7
# ..            ...              ...                     ...             ...
# 915            rb       RB F1 Team                 Italian              14
# 916        sauber           Sauber                   Swiss              16
# 917        sauber           Sauber                   Swiss              20
# 918  aston_martin     Aston Martin                 British              10
# 919        alpine   Alpine F1 Team                  French              18
#
#      end_position  points_gained race_status  laps_done  race_millis  \
# 0               1             26    Finished         57    5853584.0
# 1               2             18    Finished         57    5859182.0
# 2               3             15    Finished         57    5863259.0
# 3               4             12    Finished         57    5864795.0
# 4               5             10    Finished         57    5868338.0
# ..            ...            ...         ...        ...          ...
# 915            16              0      +1 Lap         49          NaN
# 916            17              0      +1 Lap         49          NaN
# 917            18              0      +1 Lap         49          NaN
# 918            19              0    Accident          5          NaN
# 919            20              0     Gearbox          1          NaN
#
#        race_time  fl_av_speed   fl_time  fl_lap_no  fl_rank  places_gained  \
# 0    1:37:33.584      206.018  1:34.570       51.0      1.0              0
# 1         +5.598      203.501  1:35.740       52.0      3.0              1
# 2         +9.675      202.469  1:36.228       53.0      5.0              2
# 3        +11.211      202.313  1:36.302       56.0      6.0              5
# 4        +14.754      201.641  1:36.623       53.0      8.0              2
# ..           ...          ...       ...        ...      ...            ...
# 915          NaN      238.166  1:33.323       47.0     16.0             -2
# 916          NaN      239.751  1:32.706       49.0     14.0             -1
# 917          NaN      241.046  1:32.208       49.0      6.0              2
# 918          NaN      232.591  1:35.560        5.0     19.0             -9
# 919          NaN          NaN       NaN        NaN      NaN             -2
#
#      age_in_days
# 0           8921
# 1          10062
# 2          13586
# 3           8799
# 4          10758
# ..           ...
# 915        12670
# 916        12612
# 917         9050
# 918         9263
# 919        10258
#
# [920 rows x 38 columns]

# %% [markdown]
# #### Time changes
# * time_of_race
# * race_time
# * fl_time
# * race_millis

# %% [markdown]
# ##### time_of_race

# %%
# Change 'time_of_race' set to morning/afternoon/evening and the time as an int

# %%
# Look at the distribution of different times:
df.time_of_race.value_counts()
# Out:
# 13:00:00Z    360
# 17:00:00Z    100
# 05:00:00Z     80
# 15:00:00Z     60
# 18:00:00Z     60
# 19:30:00Z     40
# 11:00:00Z     40
# 14:00:00Z     40
# 12:00:00Z     40
# 19:00:00Z     40
# 20:00:00Z     40
# 06:00:00Z     20
# Name: time_of_race, dtype: int64

# %% [markdown]
# * Pick which mapping to use *****

# %%
# Function to map times to categories: AM/12-6/after6
def cat_time(time_str):
    hour = int(time_str.split(':')[0])
    if 00 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 18:
        return 'Afternoon'
    else:
        return 'Evening'

# apply the function
df['time_cat_of_race'] = df['time_of_race'].apply(cat_time)
# Out:
# <ipython-input-27-024404ed0bde>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time_cat_of_race'] = df['time_of_race'].apply(cat_time)

# %%
# Function to map times to  the hour of the start time + . + min of the start time
def map_time(time_str):
    hour = int(time_str.split(':')[0])+int(time_str.split(':')[1])/100
    return hour
    # if 00 <= hour < 12:
    #     return 'Morning'
    # elif 12 <= hour < 18:
    #     return 'Afternoon'
    # else:
    #     return 'Evening'

# apply the function
df['time_of_race'] = df['time_of_race'].apply(map_time)
# Out:
# <ipython-input-28-356feece13f5>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time_of_race'] = df['time_of_race'].apply(map_time)

# %%
df.time_of_race.value_counts()
# Out:
# 13.0    360
# 17.0    100
# 5.0      80
# 15.0     60
# 18.0     60
# 19.3     40
# 11.0     40
# 14.0     40
# 12.0     40
# 19.0     40
# 20.0     40
# 6.0      20
# Name: time_of_race, dtype: int64

# %% [markdown]
# ##### race_time

# %%
df.dtypes
# Out:
# results_id                   int64
# race_year                    int64
# race_month                   int64
# race_day                     int64
# round                        int64
# race_name                   object
# race_id                      int64
# time_of_race               float64
# circuit_name                object
# circuit_id                   int64
# location                    object
# country                     object
# lat                        float64
# lng                        float64
# drivers_id                   int64
# driverId                    object
# driver_name                 object
# code                        object
# perm_number                  int64
# driver_nationality          object
# age_in_days                  int64
# constructors_id              int64
# constructorId               object
# constructor_name            object
# constructor_nationality     object
# start_position               int64
# end_position                 int64
# points_gained                int64
# race_status                 object
# laps_done                    int64
# race_millis                float64
# race_time                   object
# fl_av_speed                float64
# fl_time                     object
# fl_lap_no                  float64
# fl_rank                    float64
# places_gained                int64
# age_in_days                  int64
# time_cat_of_race            object
# dtype: object

# %% [markdown]
# ### Nulls

# %%
# Look to see if there are nulls in the data
df.isnull().sum()
# Out:
# results_id                   0
# race_year                    0
# race_month                   0
# race_day                     0
# round                        0
# race_name                    0
# race_id                      0
# time_of_race                 0
# circuit_name                 0
# circuit_id                   0
# location                     0
# country                      0
# lat                          0
# lng                          0
# drivers_id                   0
# driverId                     0
# driver_name                  0
# code                         0
# perm_number                  0
# driver_nationality           0
# age_in_days                  0
# constructors_id              0
# constructorId                0
# constructor_name             0
# constructor_nationality      0
# start_position               0
# end_position                 0
# points_gained                0
# race_status                  0
# laps_done                    0
# race_millis                315
# race_time                  315
# fl_av_speed                 29
# fl_time                     29
# fl_lap_no                   29
# fl_rank                     29
# places_gained                0
# age_in_days                  0
# time_cat_of_race             0
# dtype: int64

# %% [markdown]
# ### Removing columns:
# Removing the ID columns
# * 'results_id', 'race_id', 'circuit_id', 'driver_id', 'constructor_id'
# * 'constructorId', 'driverId'

# %%
# Remove the ID columns
df = df.drop(['results_id', 'race_id', 'circuit_id', 'drivers_id', 'constructors_id' ], axis = 1)

# %%
# Remove alternate id columns
df = df.drop(['constructorId', 'driverId'], axis = 1)

# %% [markdown]
# * Remove lat/lng
#   - as gives same data as location/country

# %%
# Remove lat/lng
df = df.drop(['lat', 'lng'], axis = 1)

# %% [markdown]
# * Remove race_time as gives same data as race_millis

# %%
# Remove race_time as same as race_millis
df = df.drop(['race_time'], axis = 1)

# %%
df.head(20)
# Out:
#     race_year  race_month  race_day  round           race_name  time_of_race  \
# 0        2022           3        20      1  Bahrain Grand Prix          15.0
# 1        2022           3        20      1  Bahrain Grand Prix          15.0
# 2        2022           3        20      1  Bahrain Grand Prix          15.0
# 3        2022           3        20      1  Bahrain Grand Prix          15.0
# 4        2022           3        20      1  Bahrain Grand Prix          15.0
# 5        2022           3        20      1  Bahrain Grand Prix          15.0
# 6        2022           3        20      1  Bahrain Grand Prix          15.0
# 7        2022           3        20      1  Bahrain Grand Prix          15.0
# 8        2022           3        20      1  Bahrain Grand Prix          15.0
# 9        2022           3        20      1  Bahrain Grand Prix          15.0
# 10       2022           3        20      1  Bahrain Grand Prix          15.0
# 11       2022           3        20      1  Bahrain Grand Prix          15.0
# 12       2022           3        20      1  Bahrain Grand Prix          15.0
# 13       2022           3        20      1  Bahrain Grand Prix          15.0
# 14       2022           3        20      1  Bahrain Grand Prix          15.0
# 15       2022           3        20      1  Bahrain Grand Prix          15.0
# 16       2022           3        20      1  Bahrain Grand Prix          15.0
# 17       2022           3        20      1  Bahrain Grand Prix          15.0
# 18       2022           3        20      1  Bahrain Grand Prix          15.0
# 19       2022           3        20      1  Bahrain Grand Prix          15.0
#
#                      circuit_name location  country       driver_name code  \
# 0   Bahrain International Circuit   Sakhir  Bahrain   Charles Leclerc  LEC
# 1   Bahrain International Circuit   Sakhir  Bahrain      Carlos Sainz  SAI
# 2   Bahrain International Circuit   Sakhir  Bahrain    Lewis Hamilton  HAM
# 3   Bahrain International Circuit   Sakhir  Bahrain    George Russell  RUS
# 4   Bahrain International Circuit   Sakhir  Bahrain   Kevin Magnussen  MAG
# 5   Bahrain International Circuit   Sakhir  Bahrain   Valtteri Bottas  BOT
# 6   Bahrain International Circuit   Sakhir  Bahrain      Esteban Ocon  OCO
# 7   Bahrain International Circuit   Sakhir  Bahrain      Yuki Tsunoda  TSU
# 8   Bahrain International Circuit   Sakhir  Bahrain   Fernando Alonso  ALO
# 9   Bahrain International Circuit   Sakhir  Bahrain       Guanyu Zhou  ZHO
# 10  Bahrain International Circuit   Sakhir  Bahrain   Mick Schumacher  MSC
# 11  Bahrain International Circuit   Sakhir  Bahrain      Lance Stroll  STR
# 12  Bahrain International Circuit   Sakhir  Bahrain   Alexander Albon  ALB
# 13  Bahrain International Circuit   Sakhir  Bahrain  Daniel Ricciardo  RIC
# 14  Bahrain International Circuit   Sakhir  Bahrain      Lando Norris  NOR
# 15  Bahrain International Circuit   Sakhir  Bahrain   Nicholas Latifi  LAT
# 16  Bahrain International Circuit   Sakhir  Bahrain   Nico Hülkenberg  HUL
# 17  Bahrain International Circuit   Sakhir  Bahrain      Sergio Pérez  PER
# 18  Bahrain International Circuit   Sakhir  Bahrain    Max Verstappen  VER
# 19  Bahrain International Circuit   Sakhir  Bahrain      Pierre Gasly  GAS
#
#     perm_number driver_nationality  age_in_days constructor_name  \
# 0            16         Monegasque         8921          Ferrari
# 1            55            Spanish        10062          Ferrari
# 2            44            British        13586         Mercedes
# 3            63            British         8799         Mercedes
# 4            20             Danish        10758     Haas F1 Team
# 5            77            Finnish        11892       Alfa Romeo
# 6            31             French         9315   Alpine F1 Team
# 7            22           Japanese         7983       AlphaTauri
# 8            14            Spanish        14844   Alpine F1 Team
# 9            24            Chinese         8330       Alfa Romeo
# 10           47             German         8399     Haas F1 Team
# 11           18           Canadian         8543     Aston Martin
# 12           23               Thai         9493         Williams
# 13            3         Australian        11950          McLaren
# 14            4            British         8163          McLaren
# 15            6           Canadian         9761         Williams
# 16           27             German        12632     Aston Martin
# 17           11            Mexican        11741         Red Bull
# 18           33              Dutch         8937         Red Bull
# 19           10             French         9538       AlphaTauri
#
#    constructor_nationality  start_position  end_position  points_gained  \
# 0                  Italian               1             1             26
# 1                  Italian               3             2             18
# 2                   German               5             3             15
# 3                   German               9             4             12
# 4                 American               7             5             10
# 5                    Swiss               6             6              8
# 6                   French              11             7              6
# 7                  Italian              16             8              4
# 8                   French               8             9              2
# 9                    Swiss              15            10              1
# 10                American              12            11              0
# 11                 British              19            12              0
# 12                 British              14            13              0
# 13                 British              18            14              0
# 14                 British              13            15              0
# 15                 British              20            16              0
# 16                 British              17            17              0
# 17                Austrian               4            18              0
# 18                Austrian               2            19              0
# 19                 Italian              10            20              0
#
#       race_status  laps_done  race_millis  fl_av_speed   fl_time  fl_lap_no  \
# 0        Finished         57    5853584.0      206.018  1:34.570       51.0
# 1        Finished         57    5859182.0      203.501  1:35.740       52.0
# 2        Finished         57    5863259.0      202.469  1:36.228       53.0
# 3        Finished         57    5864795.0      202.313  1:36.302       56.0
# 4        Finished         57    5868338.0      201.641  1:36.623       53.0
# 5        Finished         57    5869703.0      201.691  1:36.599       53.0
# 6        Finished         57    5873007.0      200.630  1:37.110       53.0
# 7        Finished         57    5873970.0      200.642  1:37.104       53.0
# 8        Finished         57    5875974.0      201.412  1:36.733       44.0
# 9        Finished         57    5876648.0      201.512  1:36.685       39.0
# 10       Finished         57    5886158.0      200.948  1:36.956       37.0
# 11       Finished         57    5899457.0      200.555  1:37.146       49.0
# 12       Finished         57    5907516.0      200.125  1:37.355       50.0
# 13       Finished         57    5908559.0      200.318  1:37.261       50.0
# 14       Finished         57    5909919.0      200.882  1:36.988       51.0
# 15       Finished         57    5915379.0      198.300  1:38.251       51.0
# 16       Finished         57    5917413.0      198.401  1:38.201       49.0
# 17  Fuel pressure         56          NaN      202.762  1:36.089       52.0
# 18  Fuel pressure         54          NaN      204.140  1:35.440       51.0
# 19     Power Unit         44          NaN      200.189  1:37.324       34.0
#
#     fl_rank  places_gained  age_in_days time_cat_of_race
# 0       1.0              0         8921        Afternoon
# 1       3.0              1        10062        Afternoon
# 2       5.0              2        13586        Afternoon
# 3       6.0              5         8799        Afternoon
# 4       8.0              2        10758        Afternoon
# 5       7.0              0        11892        Afternoon
# 6      14.0              4         9315        Afternoon
# 7      13.0              8         7983        Afternoon
# 8      10.0             -1        14844        Afternoon
# 9       9.0              5         8330        Afternoon
# 10     11.0              1         8399        Afternoon
# 11     15.0              7         8543        Afternoon
# 12     18.0              1         9493        Afternoon
# 13     16.0              4        11950        Afternoon
# 14     12.0             -2         8163        Afternoon
# 15     20.0              4         9761        Afternoon
# 16     19.0              0        12632        Afternoon
# 17      4.0            -14        11741        Afternoon
# 18      2.0            -17         8937        Afternoon
# 19     17.0            -10         9538        Afternoon

# %% [markdown]
# ### Identify OHE columns

# %% [markdown]
# Columns to OHE:
# * race name
# * (remove circuit_name and location)
# * country
# * code - driver (remove driver_name)
# * constuctor_name
# * constructor_nationality
# * race_status
#
# * time_cat_of_race

# %% [markdown]
# # Download Cleaned Data

# %%
df.dtypes
# Out:
# race_year                    int64
# race_month                   int64
# race_day                     int64
# round                        int64
# race_name                   object
# time_of_race               float64
# circuit_name                object
# location                    object
# country                     object
# driver_name                 object
# code                        object
# perm_number                  int64
# driver_nationality          object
# age_in_days                  int64
# constructor_name            object
# constructor_nationality     object
# start_position               int64
# end_position                 int64
# points_gained                int64
# race_status                 object
# laps_done                    int64
# race_millis                float64
# fl_av_speed                float64
# fl_time                     object
# fl_lap_no                  float64
# fl_rank                    float64
# places_gained                int64
# age_in_days                  int64
# time_cat_of_race            object
# dtype: object

# %%
# Download the Dataframe as CSV
df.to_csv('clean_data.csv', index=False)
