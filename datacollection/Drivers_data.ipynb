# %% [markdown]
# <a href="https://colab.research.google.com/github/nat13lla/Capstone/blob/main/datacollection/Drivers_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection

# %%
# Imports:
import pandas as pd
import numpy as np
import requests # default library for talking to the web
from pprint import pprint # 'Pretty Print': prints less offensive JSON

# %% [markdown]
# #Drivers 2022

# %%
# Connect to the API
url22 = 'http://ergast.com/api/f1/2022/drivers.json'
# Get a response
response = requests.get(url22)
print(response)

# 200 - Life is good :)
# 404 - Life is bad :(
# 400 - Your request is nonsense
# Out:
# <Response [200]>

# %%
# Data output
data22 = response.json()

pprint(data22)
# Out:
# {'MRData': {'DriverTable': {'Drivers': [{'code': 'ALB',
#                                          'dateOfBirth': '1996-03-23',
#                                          'driverId': 'albon',
#                                          'familyName': 'Albon',
#                                          'givenName': 'Alexander',
#                                          'nationality': 'Thai',
#                                          'permanentNumber': '23',
#                                          'url': 'http://en.wikipedia.org/wiki/Alexander_Albon'},
#                                         {'code': 'ALO',
#                                          'dateOfBirth': '1981-07-29',
#                                          'driverId': 'alonso',
#                                          'familyName': 'Alonso',
#                                          'givenName': 'Fernando',
#                                          'nationality': 'Spanish',
# ...

# %%
# Create a dataframe containing all the data
drivers_data22 = data22['MRData']['DriverTable']['Drivers']
drivers_22 = pd.DataFrame(drivers_data22)

# Show
drivers_22
# Out:
#            driverId permanentNumber code  \
# 0             albon              23  ALB
# 1            alonso              14  ALO
# 2            bottas              77  BOT
# 3          de_vries              21  DEV
# 4             gasly              10  GAS
# 5          hamilton              44  HAM
# 6        hulkenberg              27  HUL
# 7            latifi               6  LAT
# 8           leclerc              16  LEC
# 9   kevin_magnussen              20  MAG
# 10           norris               4  NOR
# 11             ocon              31  OCO
# 12            perez              11  PER
# 13        ricciardo               3  RIC
# 14          russell              63  RUS
# 15            sainz              55  SAI
# 16  mick_schumacher              47  MSC
# 17           stroll              18  STR
# 18          tsunoda              22  TSU
# 19   max_verstappen              33  VER
# 20           vettel               5  VET
# 21             zhou              24  ZHO
#
# ...

# %%
# Download the Dataframe as CSV
drivers_22.to_csv('drivers_22.csv', index=False)

# %% [markdown]
# # Drivers 2023:

# %%
# Connect to the API
url23 = 'http://ergast.com/api/f1/2023/drivers.json'
# Get a response
response = requests.get(url23)
print(response)

# 200 - Life is good :)
# 404 - Life is bad :(
# 400 - Your request is nonsense
# Out:
# <Response [200]>

# %%
# Data output
data23 = response.json()
pprint(data23)
# Out:
# {'MRData': {'DriverTable': {'Drivers': [{'code': 'ALB',
#                                          'dateOfBirth': '1996-03-23',
#                                          'driverId': 'albon',
#                                          'familyName': 'Albon',
#                                          'givenName': 'Alexander',
#                                          'nationality': 'Thai',
#                                          'permanentNumber': '23',
#                                          'url': 'http://en.wikipedia.org/wiki/Alexander_Albon'},
#                                         {'code': 'ALO',
#                                          'dateOfBirth': '1981-07-29',
#                                          'driverId': 'alonso',
#                                          'familyName': 'Alonso',
#                                          'givenName': 'Fernando',
#                                          'nationality': 'Spanish',
# ...

# %%
# Create a dataframe containing all the data
drivers_data23 = data23['MRData']['DriverTable']['Drivers']
drivers_23 = pd.DataFrame(drivers_data23)

# Show
drivers_23
# Out:
#            driverId permanentNumber code  \
# 0             albon              23  ALB
# 1            alonso              14  ALO
# 2            bottas              77  BOT
# 3          de_vries              21  DEV
# 4             gasly              10  GAS
# 5          hamilton              44  HAM
# 6        hulkenberg              27  HUL
# 7            lawson              40  LAW
# 8           leclerc              16  LEC
# 9   kevin_magnussen              20  MAG
# 10           norris               4  NOR
# 11             ocon              31  OCO
# 12            perez              11  PER
# 13          piastri              81  PIA
# 14        ricciardo               3  RIC
# 15          russell              63  RUS
# 16            sainz              55  SAI
# 17         sargeant               2  SAR
# 18           stroll              18  STR
# 19          tsunoda              22  TSU
# 20   max_verstappen              33  VER
# 21             zhou              24  ZHO
#
# ...

# %%
# Download the Dataframe as CSV
drivers_23.to_csv('drivers_23.csv', index=False)

# %% [markdown]
# # Drivers 2024:

# %%
# Connect to the API
url24 = 'http://ergast.com/api/f1/2024/drivers.json'
# Get a response
response = requests.get(url24)
print(response)

# 200 - Life is good :)
# 404 - Life is bad :(
# 400 - Your request is nonsense
# Out:
# <Response [200]>

# %%
# Data output
data24 = response.json()
pprint(data24)
# Out:
# {'MRData': {'DriverTable': {'Drivers': [{'code': 'ALB',
#                                          'dateOfBirth': '1996-03-23',
#                                          'driverId': 'albon',
#                                          'familyName': 'Albon',
#                                          'givenName': 'Alexander',
#                                          'nationality': 'Thai',
#                                          'permanentNumber': '23',
#                                          'url': 'http://en.wikipedia.org/wiki/Alexander_Albon'},
#                                         {'code': 'ALO',
#                                          'dateOfBirth': '1981-07-29',
#                                          'driverId': 'alonso',
#                                          'familyName': 'Alonso',
#                                          'givenName': 'Fernando',
#                                          'nationality': 'Spanish',
# ...

# %%
# Create a dataframe containing all the data
drivers_data24 = data24['MRData']['DriverTable']['Drivers']
drivers_24 = pd.DataFrame(drivers_data24)

# Show
drivers_24
# Out:
#            driverId permanentNumber code  \
# 0             albon              23  ALB
# 1            alonso              14  ALO
# 2           bearman              38  BEA
# 3            bottas              77  BOT
# 4             gasly              10  GAS
# 5          hamilton              44  HAM
# 6        hulkenberg              27  HUL
# 7           leclerc              16  LEC
# 8   kevin_magnussen              20  MAG
# 9            norris               4  NOR
# 10             ocon              31  OCO
# 11            perez              11  PER
# 12          piastri              81  PIA
# 13        ricciardo               3  RIC
# 14          russell              63  RUS
# 15            sainz              55  SAI
# 16         sargeant               2  SAR
# 17           stroll              18  STR
# 18          tsunoda              22  TSU
# 19   max_verstappen              33  VER
# 20             zhou              24  ZHO
#
# ...

# %%
# Download the Dataframe as CSV
drivers_24.to_csv('drivers_24.csv', index=False)

# %% [markdown]
# # Combine into 1

# %%
# Concatenate the drivers from all 3 seasons
combined_drivers = pd.concat([drivers_22, drivers_23, drivers_24])
combined_drivers
# Out:
#           driverId permanentNumber code  \
# 0            albon              23  ALB
# 1           alonso              14  ALO
# 2           bottas              77  BOT
# 3         de_vries              21  DEV
# 4            gasly              10  GAS
# ..             ...             ...  ...
# 16        sargeant               2  SAR
# 17          stroll              18  STR
# 18         tsunoda              22  TSU
# 19  max_verstappen              33  VER
# 20            zhou              24  ZHO
#
#                                              url  givenName  familyName  \
# 0   http://en.wikipedia.org/wiki/Alexander_Albon  Alexander       Albon
# 1   http://en.wikipedia.org/wiki/Fernando_Alonso   Fernando      Alonso
# 2   http://en.wikipedia.org/wiki/Valtteri_Bottas   Valtteri      Bottas
# 3     http://en.wikipedia.org/wiki/Nyck_de_Vries       Nyck    de Vries
# 4      http://en.wikipedia.org/wiki/Pierre_Gasly     Pierre       Gasly
# ...

# %%
# Drop the Duplicated Drivers
combined_drivers = combined_drivers.drop_duplicates()
combined_drivers.reset_index(drop=True, inplace=True)
combined_drivers
# Out:
#            driverId permanentNumber code  \
# 0             albon              23  ALB
# 1            alonso              14  ALO
# 2            bottas              77  BOT
# 3          de_vries              21  DEV
# 4             gasly              10  GAS
# 5          hamilton              44  HAM
# 6        hulkenberg              27  HUL
# 7            latifi               6  LAT
# 8           leclerc              16  LEC
# 9   kevin_magnussen              20  MAG
# 10           norris               4  NOR
# 11             ocon              31  OCO
# 12            perez              11  PER
# 13        ricciardo               3  RIC
# 14          russell              63  RUS
# 15            sainz              55  SAI
# 16  mick_schumacher              47  MSC
# 17           stroll              18  STR
# 18          tsunoda              22  TSU
# 19   max_verstappen              33  VER
# 20           vettel               5  VET
# 21             zhou              24  ZHO
# ...

# %%
# Add in a id column
drivers_id = combined_drivers.copy()  # Make a copy
drivers_id['drivers_id'] = combined_drivers.index + 1  # Add column id

# Set as index
drivers_id.set_index('drivers_id', inplace=True)

# Show
drivers_id
# Out:
#                    driverId permanentNumber code  \
# drivers_id
# 1                     albon              23  ALB
# 2                    alonso              14  ALO
# 3                    bottas              77  BOT
# 4                  de_vries              21  DEV
# 5                     gasly              10  GAS
# 6                  hamilton              44  HAM
# 7                hulkenberg              27  HUL
# 8                    latifi               6  LAT
# 9                   leclerc              16  LEC
# 10          kevin_magnussen              20  MAG
# 11                   norris               4  NOR
# 12                     ocon              31  OCO
# 13                    perez              11  PER
# 14                ricciardo               3  RIC
# 15                  russell              63  RUS
# 16                    sainz              55  SAI
# 17          mick_schumacher              47  MSC
# 18                   stroll              18  STR
# ...

# %%
# Download the Dataframe as CSV
drivers_id.to_csv('drivers_all.csv', index=True)
